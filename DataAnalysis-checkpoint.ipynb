# %%
import pandas as pd
import numpy as np

# %%
""" **********         LOAD EXPLOR THE DATA SET:START          ********** """
df = pd.read_csv("web-page-phishing.csv")
# Explore the dataset by getting basic info
df.info() 

# Check the shape of dataset
print(f"\n Dataset shape (Rows and Column)  : {df.shape}")  
 
# Check for missing values in the dataset
total_missing_values = df.isnull().sum().sum()
print(f"\n Total missing values in dataset  : {total_missing_values}")

# Display first few rows
print("\n First 10 rows of dataset")
print(df.head(10))

# Check for duplicate values
total_duplicate_rows = df.duplicated().sum()
print(f"\n Total duplicate rows             : {total_duplicate_rows}")
